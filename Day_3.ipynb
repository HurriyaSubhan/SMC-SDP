# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/Insiya24/datasets/main/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 0      41       Yes                   Sales                 1  Life Sciences
# 1      49        No  Research & Development                 8  Life Sciences
# 2      37       Yes  Research & Development                 2          Other
# 3      33        No  Research & Development                 3  Life Sciences
# 4      27        No  Research & Development                 2        Medical
# ...   ...       ...                     ...               ...            ...
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
# ...

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=1470, step=1),
#  Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'EducationField',
#         'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#         'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#         'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'OverTime',
#         'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#         'StandardHours', 'TotalWorkingYears', 'WorkLifeBalance',
#         'YearsAtCompany', 'YearsSinceLastPromotion'],
#        dtype='object')]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'Department', 'DistanceFromHome', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'TotalWorkingYears', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsSinceLastPromotion'],
#       dtype='object')

# %%
data.head()
# Out:
#    Age Attrition              Department  DistanceFromHome EducationField  \
# 0   41       Yes                   Sales                 1  Life Sciences
# 1   49        No  Research & Development                 8  Life Sciences
# 2   37       Yes  Research & Development                 2          Other
# 3   33        No  Research & Development                 3  Life Sciences
# 4   27        No  Research & Development                 2        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0            1.0             1.0                      2.0  Female        94.0
# 1            1.0             2.0                      3.0    Male        61.0
# 2            1.0             4.0                      4.0    Male        92.0
# 3            1.0             5.0                      4.0  Female        56.0
# 4            NaN             7.0                      1.0    Male        40.0
#
# ...

# %%
data.size
# Out:
# 36750

# %%
data.shape
# Out:
# (1470, 25)

# %%
data.ndim
# Out:
# 2

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                    object
# Department                   object
# DistanceFromHome              int64
# EducationField               object
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                        int64
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
data.isnull()
# Out:
#         Age  Attrition  Department  DistanceFromHome  EducationField  \
# 0     False      False       False             False           False
# 1     False      False       False             False           False
# 2     False      False       False             False           False
# 3     False      False       False             False           False
# 4     False      False       False             False           False
# ...     ...        ...         ...               ...             ...
# 1465  False      False       False             False           False
# 1466  False      False       False             False           False
# 1467  False      False       False             False           False
# 1468  False      False       False             False           False
# 1469  False      False       False             False           False
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
data.count()
# Out:
# Age                         1470
# Attrition                   1470
# Department                  1468
# DistanceFromHome            1470
# EducationField              1451
# EmployeeCount               1468
# EmployeeNumber              1468
# EnvironmentSatisfaction     1469
# Gender                      1458
# HourlyRate                  1467
# JobInvolvement              1449
# JobLevel                    1456
# JobSatisfaction             1459
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# OverTime                    1470
# PercentSalaryHike           1464
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# TotalWorkingYears           1470
# WorkLifeBalance             1470
# YearsAtCompany              1470
# YearsSinceLastPromotion     1470
# dtype: int64

# %%
data.values
# Out:
# array([[41, 'Yes', 'Sales', ..., 1, 6, 0],
#        [49, 'No', 'Research & Development', ..., 3, 10, 1],
#        [37, 'Yes', 'Research & Development', ..., 3, 0, 0],
#        ...,
#        [27, 'No', 'Research & Development', ..., 3, 6, 0],
#        [49, 'No', 'Sales', ..., 2, 9, 0],
#        [34, 'No', 'Research & Development', ..., 4, 4, 1]], dtype=object)

# %%
data.tail()
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1467   27        No  Research & Development                 4  Life Sciences
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1465            1.0          2061.0                      3.0   Male
# 1466            1.0          2062.0                      4.0   Male
# 1467            1.0          2064.0                      2.0   Male
# 1468            1.0          2065.0                      4.0   Male
# 1469            1.0          2068.0                      2.0   Male
#
#       HourlyRate  ...  MonthlyRate  OverTime  PercentSalaryHike  \
# ...

# %% [markdown]
# AGGREGATE FUNCTIONS:

# %%
data[data["Age"]>30.0]
# Out:
#       Age Attrition              Department  DistanceFromHome EducationField  \
# 0      41       Yes                   Sales                 1  Life Sciences
# 1      49        No  Research & Development                 8  Life Sciences
# 2      37       Yes  Research & Development                 2          Other
# 3      33        No  Research & Development                 3  Life Sciences
# 5      32        No  Research & Development                 2  Life Sciences
# ...   ...       ...                     ...               ...            ...
# 1463   31        No  Research & Development                 5        Medical
# 1465   36        No  Research & Development                23        Medical
# 1466   39        No  Research & Development                 6        Medical
# 1468   49        No                   Sales                 2        Medical
# 1469   34        No  Research & Development                 8        Medical
#
# ...

# %% [markdown]
# GROUP BY FUNCTION:

# %%
data_EF=data.groupby(["Age"])[["DistanceFromHome"]]

# %% [markdown]
# FILLING NULL VALUES AKA FEAUTURE ENGG.

# %%
data['MonthlyRate'].mean()
# Out:
# 14313.103401360544

# %%
data['MonthlyRate'].fillna(14313.103,inplace=True)

# %%
data['EmployeeCount'].mean()
# Out:
# 1.0

# %%
data['EmployeeCount'].fillna(1.0,inplace=True)

# %%
data['PercentSalaryHike'].mean()
# Out:
# 15.220628415300547

# %%
data['PercentSalaryHike'].fillna(15.220,inplace=True)

# %%
data.isna().sum()
# Out:
# Age                          0
# Attrition                    0
# Department                   2
# DistanceFromHome             0
# EducationField              19
# EmployeeCount                0
# EmployeeNumber               2
# EnvironmentSatisfaction      1
# Gender                      12
# HourlyRate                   3
# JobInvolvement              21
# JobLevel                    14
# JobSatisfaction             11
# MaritalStatus                0
# MonthlyIncome                0
# MonthlyRate                  0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# TotalWorkingYears            0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsSinceLastPromotion      0
# dtype: int64

# %% [markdown]
# LABEL ENCODING

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# Department                    int64
# DistanceFromHome              int64
# EducationField                int64
# EmployeeCount               float64
# EmployeeNumber              float64
# EnvironmentSatisfaction     float64
# Gender                        int64
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobSatisfaction             float64
# MaritalStatus                 int64
# MonthlyIncome                 int64
# MonthlyRate                   int64
# OverTime                      int64
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StandardHours                 int64
# TotalWorkingYears             int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsSinceLastPromotion       int64
# dtype: object

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      874
# Female    584
# Name: count, dtype: int64

# %%
data["Gender"]=le.fit_transform(data["Gender"])

# %%
data['Gender'].value_counts()
# Out:
# Gender
# 1    874
# 0    584
# 2     12
# Name: count, dtype: int64

# %%
data['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
data["MaritalStatus"]=le.fit_transform(data["MaritalStatus"])

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
data["Attrition"]=le.fit_transform(data["Attrition"])

# %%
data['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     444
# Human Resources            63
# Name: count, dtype: int64

# %%
data["Department"]=le.fit_transform(data["Department"])

# %%
data['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       600
# Medical             454
# Marketing           159
# Technical Degree    131
# Other                81
# Human Resources      26
# Name: count, dtype: int64

# %%
data["EducationField"]=le.fit_transform(data["EducationField"])

# %%
data['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
data["OverTime"]=le.fit_transform(data["OverTime"])

# %%
import seaborn
import matplotlib.pyplot as pt
pt.figure(figsize=(14,16))
correlation = data.corr ()
heatmap = seaborn.heatmap(correlation, annot = True)

pt.show()
